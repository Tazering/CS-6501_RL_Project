# %%
import gymnasium as gym
from gymnasium.wrappers import TimeLimit
import mani_skill.envs
from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.env_checker import check_env
from mani_skill.utils import gym_utils
from mani_skill.utils.wrappers.record import RecordEpisode
from mani_skill.vector.wrappers.sb3 import ManiSkillSB3VectorEnv
import torch
import numpy as np
import matplotlib.pyplot as plt

SEED = 17
NUM_ENVS = 8
total_timesteps = 200000

# %%
env = gym.make("CartPole-v1", render_mode = "rgb_array")
states, _ = env.reset()
check_env(env, warn = True)

# %%
dqn_model = DQN(policy = "MlpPolicy", buffer_size = 10000, tau = 1.0, target_update_interval = 1000, env = env, learning_rate = 1e-3, 
batch_size = 64, gamma = .99, exploration_fraction = .1, learning_starts = 1000, verbose = 1, exploration_final_eps = .01)
dqn_model.learn(total_timesteps = total_timesteps, progress_bar = True)
dqn_model.save("dqn_cartpole")
# Out:
# Output()
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.2     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 5236     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 109      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 5967     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 186      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 6839     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 257      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 7487     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 328      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 8465     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 472      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 8825     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 558      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 8978     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 633      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 9177     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 721      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 9497     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 839      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 9594     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 905      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 9726     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 977      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 8026     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1032     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.367    |
# |    n_updates        | 7        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 5953     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1124     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0196   |
# |    n_updates        | 30       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4684     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1235     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00269  |
# |    n_updates        | 58       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 3757     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1316     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00132  |
# |    n_updates        | 78       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 3566     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1378     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000721 |
# |    n_updates        | 94       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 3278     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1475     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000668 |
# |    n_updates        | 118      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 3125     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1556     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000217 |
# |    n_updates        | 138      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2917     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1646     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000264 |
# |    n_updates        | 161      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2747     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1751     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000213 |
# |    n_updates        | 187      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2589     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1848     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000152 |
# |    n_updates        | 211      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2485     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1956     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000304 |
# |    n_updates        | 238      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 2392     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2038     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0357   |
# |    n_updates        | 259      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 2168     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2126     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0322   |
# |    n_updates        | 281      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2014     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2219     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0259   |
# |    n_updates        | 304      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1908     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2330     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0175   |
# |    n_updates        | 332      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1872     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2441     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0405   |
# |    n_updates        | 360      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1868     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2504     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0136   |
# |    n_updates        | 375      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1851     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2584     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0332   |
# |    n_updates        | 395      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1833     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2706     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0154   |
# |    n_updates        | 426      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1823     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2776     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0116   |
# |    n_updates        | 443      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1812     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2860     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.012    |
# |    n_updates        | 464      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1803     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2921     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.015    |
# |    n_updates        | 480      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1780     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3086     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0396   |
# |    n_updates        | 521      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1776     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3138     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0445   |
# |    n_updates        | 534      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1766     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3275     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0651   |
# |    n_updates        | 568      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1754     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3383     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0492   |
# |    n_updates        | 595      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.826    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1741     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3521     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0462   |
# |    n_updates        | 630      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1737     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3608     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.033    |
# |    n_updates        | 651      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1728     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3685     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0318   |
# |    n_updates        | 671      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.8     |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1674     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3857     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0402   |
# |    n_updates        | 714      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.8     |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1623     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3951     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0309   |
# |    n_updates        | 737      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.8     |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1595     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4035     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.248    |
# |    n_updates        | 758      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.1     |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1539     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4157     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0362   |
# |    n_updates        | 789      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.6     |
# |    ep_rew_mean      | 25.6     |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1504     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4309     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.115    |
# |    n_updates        | 827      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.5     |
# |    ep_rew_mean      | 26.5     |
# |    exploration_rate | 0.778    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1448     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4494     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00468  |
# |    n_updates        | 873      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.5     |
# |    ep_rew_mean      | 27.5     |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1351     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4709     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0163   |
# |    n_updates        | 927      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.8     |
# |    ep_rew_mean      | 27.8     |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1314     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4820     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0476   |
# |    n_updates        | 954      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 29.2     |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1320     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5049     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.181    |
# |    n_updates        | 1012     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 29.6     |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1323     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5182     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0665   |
# |    n_updates        | 1045     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.2     |
# |    ep_rew_mean      | 30.2     |
# |    exploration_rate | 0.735    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1328     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5353     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0837   |
# |    n_updates        | 1088     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.3     |
# |    ep_rew_mean      | 31.3     |
# |    exploration_rate | 0.724    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1334     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5572     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0758   |
# |    n_updates        | 1142     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.4     |
# |    ep_rew_mean      | 31.4     |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1334     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5643     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.14     |
# |    n_updates        | 1160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.2     |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.712    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1338     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5809     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0831   |
# |    n_updates        | 1202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | 33.8     |
# |    exploration_rate | 0.699    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1341     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6086     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0837   |
# |    n_updates        | 1271     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.6     |
# |    ep_rew_mean      | 36.6     |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1347     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6435     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0393   |
# |    n_updates        | 1358     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.8     |
# |    ep_rew_mean      | 38.8     |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1353     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6735     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.073    |
# |    n_updates        | 1433     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.4     |
# |    ep_rew_mean      | 39.4     |
# |    exploration_rate | 0.661    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1355     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6856     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00659  |
# |    n_updates        | 1463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.6     |
# |    ep_rew_mean      | 39.6     |
# |    exploration_rate | 0.651    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1358     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7047     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0703   |
# |    n_updates        | 1511     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.3     |
# |    ep_rew_mean      | 41.3     |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1359     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7268     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.112    |
# |    n_updates        | 1566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.5     |
# |    ep_rew_mean      | 42.5     |
# |    exploration_rate | 0.627    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1362     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7526     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.123    |
# |    n_updates        | 1631     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.9     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.615    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1363     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7777     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.155    |
# |    n_updates        | 1694     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.9     |
# |    ep_rew_mean      | 44.9     |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1363     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8007     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.371    |
# |    n_updates        | 1751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46.5     |
# |    ep_rew_mean      | 46.5     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1364     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8257     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0652   |
# |    n_updates        | 1814     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.8     |
# |    ep_rew_mean      | 48.8     |
# |    exploration_rate | 0.576    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1362     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8561     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0654   |
# |    n_updates        | 1890     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.3     |
# |    ep_rew_mean      | 50.3     |
# |    exploration_rate | 0.56     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1362     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8891     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.06     |
# |    n_updates        | 1972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.1     |
# |    ep_rew_mean      | 53.1     |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1363     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9257     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.181    |
# |    n_updates        | 2064     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56       |
# |    ep_rew_mean      | 56       |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1363     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 9639     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0417   |
# |    n_updates        | 2159     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 59.5     |
# |    ep_rew_mean      | 59.5     |
# |    exploration_rate | 0.5      |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1361     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 10103    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.042    |
# |    n_updates        | 2275     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.7     |
# |    ep_rew_mean      | 62.7     |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1330     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 10583    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0168   |
# |    n_updates        | 2395     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.2     |
# |    ep_rew_mean      | 67.2     |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1328     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 11213    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0427   |
# |    n_updates        | 2553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.9     |
# |    ep_rew_mean      | 69.9     |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1325     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 11697    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.102    |
# |    n_updates        | 2674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.7     |
# |    ep_rew_mean      | 76.7     |
# |    exploration_rate | 0.382    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1322     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 12492    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.284    |
# |    n_updates        | 2872     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.1     |
# |    ep_rew_mean      | 82.1     |
# |    exploration_rate | 0.344    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1318     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 13260    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0115   |
# |    n_updates        | 3064     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | 89.4     |
# |    exploration_rate | 0.301    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1312     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 14119    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.151    |
# |    n_updates        | 3279     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98       |
# |    ep_rew_mean      | 98       |
# |    exploration_rate | 0.25     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1305     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 15155    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0169   |
# |    n_updates        | 3538     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.199    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1281     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 16184    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.352    |
# |    n_updates        | 3795     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.155    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1274     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 17079    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0389   |
# |    n_updates        | 4019     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 122      |
# |    ep_rew_mean      | 122      |
# |    exploration_rate | 0.106    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1267     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 18052    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.379    |
# |    n_updates        | 4262     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 131      |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.0515   |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1256     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 19161    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00626  |
# |    n_updates        | 4540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1244     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 20241    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00251  |
# |    n_updates        | 4810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1226     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 21181    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00427  |
# |    n_updates        | 5045     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1219     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 22175    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00373  |
# |    n_updates        | 5293     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1213     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 23383    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.372    |
# |    n_updates        | 5595     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1207     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 24504    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000933 |
# |    n_updates        | 5875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1192     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 25547    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00138  |
# |    n_updates        | 6136     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1188     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 26394    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00184  |
# |    n_updates        | 6348     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1184     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 27265    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000563 |
# |    n_updates        | 6566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1181     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 28168    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.381    |
# |    n_updates        | 6791     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1179     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 29108    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0149   |
# |    n_updates        | 7026     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 211      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1168     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 30001    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.282    |
# |    n_updates        | 7250     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1165     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 30847    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00384  |
# |    n_updates        | 7461     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1163     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 31728    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00623  |
# |    n_updates        | 7681     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1159     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 32771    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000736 |
# |    n_updates        | 7942     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    loss             | 2.38     |
# |    n_updates        | 44878    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | 90.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2028     |
# |    fps              | 1067     |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 180707   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.49     |
# |    n_updates        | 44926    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | 89.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2032     |
# |    fps              | 1067     |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 181027   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0355   |
# |    n_updates        | 45006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.5     |
# |    ep_rew_mean      | 88.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2036     |
# |    fps              | 1067     |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 181318   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.48     |
# |    n_updates        | 45079    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.5     |
# |    ep_rew_mean      | 88.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2040     |
# |    fps              | 1067     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 181722   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.31     |
# |    n_updates        | 45180    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.6     |
# |    ep_rew_mean      | 87.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2044     |
# |    fps              | 1067     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 182035   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.34     |
# |    n_updates        | 45258    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.5     |
# |    ep_rew_mean      | 86.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2048     |
# |    fps              | 1067     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 182329   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.94     |
# |    n_updates        | 45332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.7     |
# |    ep_rew_mean      | 86.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2052     |
# |    fps              | 1067     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 182744   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.949    |
# |    n_updates        | 45435    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.4     |
# |    ep_rew_mean      | 85.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2056     |
# |    fps              | 1067     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 183065   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.907    |
# |    n_updates        | 45516    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.1     |
# |    ep_rew_mean      | 84.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2060     |
# |    fps              | 1068     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 183367   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.941    |
# |    n_updates        | 45591    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.9     |
# |    ep_rew_mean      | 83.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2064     |
# |    fps              | 1068     |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 183769   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0187   |
# |    n_updates        | 45692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.6     |
# |    ep_rew_mean      | 84.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2068     |
# |    fps              | 1068     |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 184181   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0126   |
# |    n_updates        | 45795    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.5     |
# |    ep_rew_mean      | 83.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2072     |
# |    fps              | 1068     |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 184500   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0448   |
# |    n_updates        | 45874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.9     |
# |    ep_rew_mean      | 83.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2076     |
# |    fps              | 1067     |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 184938   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.66     |
# |    n_updates        | 45984    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85       |
# |    ep_rew_mean      | 85       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2080     |
# |    fps              | 1067     |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 185392   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.961    |
# |    n_updates        | 46097    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.7     |
# |    ep_rew_mean      | 84.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2084     |
# |    fps              | 1068     |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 185754   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00558  |
# |    n_updates        | 46188    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.6     |
# |    ep_rew_mean      | 85.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2088     |
# |    fps              | 1068     |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 186230   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0311   |
# |    n_updates        | 46307    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | 90.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2092     |
# |    fps              | 1068     |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 187094   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0812   |
# |    n_updates        | 46523    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | 91       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2096     |
# |    fps              | 1068     |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 187581   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.46     |
# |    n_updates        | 46645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | 95.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2100     |
# |    fps              | 1069     |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 188488   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0151   |
# |    n_updates        | 46871    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | 98.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2104     |
# |    fps              | 1069     |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 189037   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0279   |
# |    n_updates        | 47009    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2108     |
# |    fps              | 1069     |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 189659   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.886    |
# |    n_updates        | 47164    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 103      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2112     |
# |    fps              | 1068     |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 190284   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0256   |
# |    n_updates        | 47320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2116     |
# |    fps              | 1069     |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 190623   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00787  |
# |    n_updates        | 47405    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2120     |
# |    fps              | 1069     |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 191273   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0126   |
# |    n_updates        | 47568    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2124     |
# |    fps              | 1069     |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 191913   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0166   |
# |    n_updates        | 47728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2128     |
# |    fps              | 1069     |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 192694   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0109   |
# |    n_updates        | 47923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2132     |
# |    fps              | 1070     |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 193967   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.98     |
# |    n_updates        | 48241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 143      |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2136     |
# |    fps              | 1069     |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 195623   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.5      |
# |    n_updates        | 48655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2140     |
# |    fps              | 1070     |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 197623   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00638  |
# |    n_updates        | 49155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2144     |
# |    fps              | 1071     |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 199623   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00417  |
# |    n_updates        | 49655    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
eval_env = gym.make("CartPole-v1", render_mode = "rgb_array")

def get_total_reward(model_name, eval_env, episodes = 10):

    model = DQN.load(model_name)
    total_rewards_list = []

    for ep in range(episodes):
        obs, _ = eval_env.reset()
        done = False
        total_reward = 0
        truncated = False

        while not done:
            action, _states = model.predict(obs, deterministic = True)
            obs, reward, done, truncated, info = eval_env.step(action)
            total_reward += reward
            
            if truncated:
                break

        total_rewards_list.append(total_reward)
        print(f"Episode: {ep}\nTotal Rewards {total_reward}")
    
    return total_rewards_list

# %%
total_rewards = get_total_reward("dqn_cartpole", eval_env)
print(total_rewards)
# Out:
# Episode: 0
# Total Rewards 500.0
# Episode: 1
# Total Rewards 500.0
# Episode: 2
# Total Rewards 500.0
# Episode: 3
# Total Rewards 500.0
# Episode: 4
# Total Rewards 500.0
# Episode: 5
# Total Rewards 500.0
# Episode: 6
# Total Rewards 500.0
# Episode: 7
# Total Rewards 500.0
# Episode: 8
# Total Rewards 500.0
# Episode: 9
# Total Rewards 500.0
# [500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0]

# %%
plt.title("DQN Average Reward")
plt.plot(total_rewards, color = "red", label = "alpha = .01")
plt.legend()
plt.xlabel("Episode Steps")
plt.ylabel("Average Reward")
plt.show()

# %%
import os
import imageio

# record a video
print("Recording a video...")
video_frames = []
obs, _ = eval_env.reset()
done = False

while not done:
    frame = eval_env.render()
    video_frames.append(frame)
    action, _ = dqn_model.predict(obs, deterministic = True)
    obs, reward, done, truncated, info = eval_env.step(action)
    if truncated:
        break

eval_env.close()

# save the video
os.makedirs("videos", exist_ok = True)
video_path = os.path.join("videos", "dqn_cartpole_video.mp4")
imageio.mimsave(video_path, video_frames, fps = 30)
print(f"Video saved to {video_path}")
# Out:
# Recording a video...
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# [swscaler @ 0x716cf00] Warning: data is not aligned! This can lead to a speed loss
# Video saved to videos/dqn_cartpole_video.mp4
